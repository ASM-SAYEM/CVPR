# %% [markdown]
# # NAME: A.S.M. SAYEM
# # ID: 20-44115-2
# # ASSIGNMENT 1

# %%
import os
import random
import numpy as np
import cv2
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
import pickle
import platform
import pandas as pd
from PIL import Image
import glob
import random

# %%
TRAIN_DIR = r"C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train"
CATEGORIES = [c for c in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, c))]
print(CATEGORIES)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# # Convert To Grascale

# %%
#specify the image path and the destination path for airplane
img_path = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\airplane'
dest_path = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\grayscale'

img_path2 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\automobile'


img_path3 = r'/C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\bird'

img_path4 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\cat'

img_path5 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\deer'

img_path6 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\dog'

img_path7 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\frog'

img_path8 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\horse'

img_path9 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\ship'

img_path10 = r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\train\truck'

# %%
i = 1
for img in glob.glob(img_path + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Air' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path2 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Auto' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path3 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Bird' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path4 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Cat' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path5 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Deer' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path6 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Dog' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path7 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_frog' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path8 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_horse' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path9 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Ship' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path10 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Truck' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
path=r'C:\Users\USER\Desktop\CIFAR10\CIFAR-10-images\grayscale'
images=os.listdir(path)
type(images)
len(images)
# Out:
# 45000

# %%
img_data=[]
for img in images:
    img_arr=cv2.imread(os.path.join(path,img))
    img_data.append(img_arr)

# %%
import random

plt.figure(figsize=(10,10))
num_images = 100  # Number of images to display
subset = random.sample(range(len(img_data)), num_images)  # Randomly select images

for i, idx in enumerate(subset):
    plt.subplot(10, 10, i + 1)
    plt.imshow(img_data[idx])

# %%
TRAIN_DATA = []
for c in CATEGORIES:
    path = os.path.join(TRAIN_DIR, c)
    class_num = CATEGORIES.index(c)
    count = 0  # Track the number of images processed

    for img in tqdm(os.listdir(path)):
        if count >= 500000:  # Limit the number of images to 500,000
            break

        img_arr = cv2.imread(os.path.join(path,img))
        TRAIN_DATA.append([img_arr, class_num])
        count += 1

print(len(TRAIN_DATA))
# Out:
# ...
# 100%|██████████| 5000/5000 [00:06<00:00, 755.77it/s]
# 50000

# %%
random.shuffle(TRAIN_DATA)
plt.figure(figsize=(11,7))

for i in range(50):
    plt.subplot(5,10,i+1)
    plt.imshow(TRAIN_DATA[i][0])
    plt.xlabel(CATEGORIES[TRAIN_DATA[i][1]])
    plt.xticks([])
    plt.yticks([])
    if i==50:
        break
plt.show()

# %%
f0 = TRAIN_DATA[0:1000]
f1 = TRAIN_DATA[1000:2000]
f2 = TRAIN_DATA[2000:3000]
f3 = TRAIN_DATA[3000:4000]
f4 = TRAIN_DATA[4000:5000]

# %%
k_max = 10

def l1_dist(x, y):
    return np.sum(np.abs(x - y))

def l2_dist(x, y):
    return np.sqrt(np.sum((x - y) ** 2))

def knn(train, validation, k):
    preds = []
    for v in validation:
        distances = []
        for t in train:
            l2 = l2_dist(v[0], t[0])
            distances.append((l2, t[1]))
        distances.sort(key=lambda x: x[0])
        neighbors = [d[1] for d in distances[:k]]
        counts = np.bincount(neighbors)
        pred = np.argmax(counts)
        preds.append(pred)
    return preds

mean_accuracies_l1 = []
std_accuracies_l1 = []
mean_accuracies_l2 = []
std_accuracies_l2 = []

for k in tqdm(range(1, k_max+1)):
    fold_accuracies_l1 = []
    fold_accuracies_l2 = []
    
    for i in range(5):
        if i == 0:
            train = f1+f2+f3+f4
            validation = f0
        elif i == 1:
            train = f0+f2+f3+f4
            validation = f1
        elif i == 2:
            train = f1+f0+f3+f4
            validation = f2
        elif i == 3:
            train = f1+f2+f0+f4
            validation = f3
        elif i == 4:
            train = f1+f2+f3+f0
            validation = f4

        acc_l1 = 0
        acc_l2 = 0

        for v in validation:
            l1_dists = []
            l2_dists = []
            for t in train:
                l1 = l1_dist(v[0], t[0])
                l2 = l2_dist(v[0], t[0])
                l1_dists.append((l1, t[1]))
                l2_dists.append((l2, t[1]))
            l1_dists.sort(key=lambda x: x[0])
            l2_dists.sort(key=lambda x: x[0])

            neighbors_l1 = [d[1] for d in l1_dists[:k]]
            counts_l1 = np.bincount(neighbors_l1)
            pred_l1 = np.argmax(counts_l1)

            neighbors_l2 = [d[1] for d in l2_dists[:k]]
            counts_l2 = np.bincount(neighbors_l2)
            pred_l2 = np.argmax(counts_l2)

            if pred_l1 == v[1]:
                acc_l1 += 1
            if pred_l2 == v[1]:
                acc_l2 += 1

        fold_accuracies_l1.append(acc_l1 / len(validation))
        fold_accuracies_l2.append(acc_l2 / len(validation))

    mean_accuracies_l1.append(np.mean(fold_accuracies_l1))
    std_accuracies_l1.append(np.std(fold_accuracies_l1))
    mean_accuracies_l2.append(np.mean(fold_accuracies_l2))
    std_accuracies_l2.append(np.std(fold_accuracies_l2))
# Out:
# 100%|██████████| 10/10 [2:19:58<00:00, 839.82s/it]

# %%
plt.errorbar(range(1, k_max+1), mean_accuracies_l1, yerr=std_accuracies_l1, label="L1 Distance",color="blue")
plt.errorbar(range(1, k_max+1), mean_accuracies_l2, yerr=std_accuracies_l2, label="L2 Distance",color="yellow")
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.title("L1 vs L2")
plt.legend()
plt.show()

# %% [markdown]
# # KNN

# %%
from collections import Counter

class KNearestNeighbor(object):
    def __init__(self):
        pass

    def train(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X, k=1, num_loops=0):
        if num_loops == 0:
            dists = self.compute_distances(X)
        else:
            raise ValueError('In valid value %d for num_loops' % num_loops)
        return self.predict_labels(dists, k=k)

    def compute_distances(self, X):
        num_test = X.shape[0]
        num_train = self.X_train.shape[0]
        dists = np.zeros((num_test, num_train))
        dists = np.sqrt(np.sum(np.square(self.X_train), axis=1) + np.sum(np.square(X), axis=1)[:, np.newaxis] - 2 * np.dot(X, self.X_train.T))
        return dists

    def predict_labels(self, dists, k=1):
        num_test = dists.shape[0]
        y_pred = np.zeros(num_test)
        for i in range(num_test):
            sorted_dist = np.argsort(dists[i])
            closest_y = list(self.y_train[sorted_dist[:k]])
            y_pred[i] = Counter(closest_y).most_common(1)[0][0]
        return y_pred

# %%
def load_pickle(f):
    version = platform.python_version_tuple()
    if version[0] == '2':
        return  pickle.load(f)
    elif version[0] == '3':
        return  pickle.load(f, encoding='latin1')
    raise ValueError("invalid python version: {}".format(version))

def load_CIFAR_batch(filename):
  """ load single batch of cifar """
  with open(filename, 'rb') as f:
    datadict = load_pickle(f)
    X = datadict['data']
    Y = datadict['labels']
    X = X.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float")
    Y = np.array(Y)
    return X, Y

def load_CIFAR10(ROOT):
  """ load all of cifar """
  xs = []
  ys = []
  for b in range(1,6):
    f = os.path.join(ROOT, 'data_batch_%d' % (b, ))
    X, Y = load_CIFAR_batch(f)
    xs.append(X)
    ys.append(Y)    
  Xtr = np.concatenate(xs)
  Ytr = np.concatenate(ys)
  del X, Y
  Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
  return Xtr, Ytr, Xte, Yte
cifar10_dir = './data/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)

# %%
num_training = 10000
mask = list(range(num_training))
X_train = X_train[mask]
y_train = y_train[mask]

# Memory error prevention by subsampling data

num_test = 1000
mask = list(range(num_test))
X_test = X_test[mask]
y_test = y_test[mask]

# reshaping data and placing into rows

X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
print(X_train.shape, X_test.shape)

# %%
import matplotlib.pyplot as plt

accuracies = []
k_values = range(1, 15)

for k in k_values:
    classifier = KNearestNeighbor()
    classifier.train(X_train, y_train)
    dists = classifier.compute_distances(X_test)
    y_test_pred = classifier.predict_labels(dists, k=k)
    num_correct = np.sum(y_test_pred == y_test)
    accuracy = float(num_correct) / num_test
    accuracies.append(accuracy)
    print('k = %d, Got %d / %d correct => accuracy: %f' % (k, num_correct, num_test, accuracy))

plt.plot(k_values, accuracies)
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.title('k-NN Classifier Accuracy for Different k Values')
plt.show()

# %% [markdown]
# # Cross Validation

# %%
num_folds = 5
k_choices = [1, 3, 5, 8, 10, 12, 15, 20, 50, 100]

X_train_folds = np.array_split(X_train, num_folds)
y_train_folds = np.array_split(y_train, num_folds)
k_to_accuracies = {}

for k in k_choices:
    k_to_accuracies[k] = []
    for num_knn in range(num_folds):
        X_test = X_train_folds[num_knn]
        y_test = y_train_folds[num_knn]
        X_train = np.concatenate(X_train_folds[:num_knn] + X_train_folds[num_knn+1:], axis=0)
        y_train = np.concatenate(y_train_folds[:num_knn] + y_train_folds[num_knn+1:], axis=0)

        classifier = KNearestNeighbor()
        classifier.train(X_train, y_train)
        dists = classifier.compute_distances(X_test)
        y_test_pred = classifier.predict_labels(dists, k)

        num_correct = np.sum(y_test_pred == y_test)
        accuracy = float(num_correct) / num_test
        k_to_accuracies[k].append(accuracy)

print("Printing our 5-fold accuracies for varying values of k:")
print()
for k in sorted(k_to_accuracies):
    for accuracy in k_to_accuracies[k]:
        print('k = %d, accuracy = %f' % (k, accuracy))

# %%
# plot the raw observations
for k in k_choices:
    accuracies = k_to_accuracies[k]
    plt.scatter([k] * len(accuracies), accuracies)

# plot the trend line with error bars that correspond to standard deviation
accuracies_mean = np.array([np.mean(v) for k,v in sorted(k_to_accuracies.items())])
accuracies_std = np.array([np.std(v) for k,v in sorted(k_to_accuracies.items())])
plt.errorbar(k_choices, accuracies_mean, yerr=accuracies_std)
plt.title('Cross-validation on k')
plt.xlabel('k')
plt.ylabel('Cross-validation accuracy')
plt.show()

# %%
# Choosing best value of k based on cross-validation results

best_k = 10

classifier = KNearestNeighbor()
classifier.train(X_train, y_train)
y_test_pred = classifier.predict(X_test, k=best_k)

# Computing and displaying the accuracy for best k found during cross-validation
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / num_test
print('Got %d / %d correct => accuracy: %f' % (num_correct, num_test, accuracy))

# %% [markdown]
# # Result and Discussion
# Firsty the code performs on CIFAR10 dataset to conver all the images to grascale at grascale folder.The code performs classification on a dataset using two different distance metrics: L1 distance (Manhattan distance) and L2 distance (Euclidean distance). It uses 5-fold cross-validation to evaluate the accuracies for each value of k from 1 to 20. The mean and standard deviation of the accuracies are calculated for both distance metrics. The code then plots the results, showing that the L1 accuracy is higher than the L2 accuracy in this experiment.
# The provided code implements the k-Nearest Neighbor algorithm for the CIFAR-10 dataset. Here's a breakdown of its functionality:
# The code starts by loading the CIFAR-10 dataset using the load_CIFAR10 function. This function returns the training set (X_train and y_train) and the test set (X_test and y_test).
# To reduce memory usage, the code subsamples the training and test sets. This means that it selects a smaller subset of data from the original sets to work with.
# The code defines a class called KNearestNeighbor, which represents the k-Nearest Neighbor classifier. This class has two methods: train and predict.
# The train method is responsible for saving the training data (X_train and y_train) to the object's variables. It prepares the classifier by storing the training samples and their corresponding labels.
# The predict method is used to make predictions on the test data. It first computes the distances between each test sample and all the training samples using the compute_distances method. This step calculates the similarity or dissimilarity between the test samples and the training samples.
# After computing the distances, the predict_labels method takes these distances as input and outputs the predicted labels for the test data. It uses the k nearest neighbors to determine the label for each test sample based on the labels of its closest neighbors in the training set.
# Overall, this code provides a basic implementation of the k-Nearest Neighbor algorithm for the CIFAR-10 dataset, allowing you to train the classifier on the training data and make predictions on the test data.
